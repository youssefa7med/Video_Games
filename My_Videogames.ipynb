# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy  as np

# %% [markdown]
# ## Reading Data

# %%
read = pd.read_csv(r'E:\data science\note.books\Pandas\Data Pandas\Videogames.csv')

# %%
read
# Out:
#      RANKING                             VIDEO GAME NAME                Year  \
# 0           1   The Witcher 3: Wild Hunt - Blood and Wine  (2016 Video Game)
# 1           2                      Red Dead Redemption II  (2018 Video Game)
# 2           3                    The Witcher 3: Wild Hunt  (2015 Video Game)
# 3           4                              The Last of Us  (2013 Video Game)
# 4           5              Mass Effect: Legendary Edition  (2021 Video Game)
# ..        ...                                         ...                ...
# 245       246  The Legend of Zelda: A Link Between Worlds  (2013 Video Game)
# 246       247                                  Black Mesa  (2012 Video Game)
# 247       248             Assassin's Creed IV: Black Flag  (2013 Video Game)
# 248       249        Ni no Kuni: Wrath of the White Witch  (2011 Video Game)
# 249       250                               Borderlands 2  (2012 Video Game)
#
#                           genre  Rating  \
# ...

# %% [markdown]
# ## Make a copy

# %%
df = read.copy()

# %%
df
# Out:
#      RANKING                             VIDEO GAME NAME                Year  \
# 0           1   The Witcher 3: Wild Hunt - Blood and Wine  (2016 Video Game)
# 1           2                      Red Dead Redemption II  (2018 Video Game)
# 2           3                    The Witcher 3: Wild Hunt  (2015 Video Game)
# 3           4                              The Last of Us  (2013 Video Game)
# 4           5              Mass Effect: Legendary Edition  (2021 Video Game)
# ..        ...                                         ...                ...
# 245       246  The Legend of Zelda: A Link Between Worlds  (2013 Video Game)
# 246       247                                  Black Mesa  (2012 Video Game)
# 247       248             Assassin's Creed IV: Black Flag  (2013 Video Game)
# 248       249        Ni no Kuni: Wrath of the White Witch  (2011 Video Game)
# 249       250                               Borderlands 2  (2012 Video Game)
#
#                           genre  Rating  \
# ...

# %%
df.head(3)
# Out:
#    RANKING                            VIDEO GAME NAME                Year  \
# 0         1  The Witcher 3: Wild Hunt - Blood and Wine  (2016 Video Game)
# 1         2                     Red Dead Redemption II  (2018 Video Game)
# 2         3                   The Witcher 3: Wild Hunt  (2015 Video Game)
#
#                       genre  Rating  \
# 0  Action, Adventure, Drama     9.8
# 1  Action, Adventure, Crime     9.7
# 2  Action, Adventure, Drama     9.7
#
#                                              DETAILS             DIRECTOR   \
# 0  Geralt is in the southern province of Toussain...  Konrad Tomaszkiewicz
# 1  Amidst the decline of the Wild West at the tur...  Benjamin Byron Davis
# 2  A monster hunter for hire embarks on an epic j...  Konrad Tomaszkiewicz
#
#        ACTOR-1        ACTOR-2               ACTOR-3          ACTOR-4  VOTES   \
# 0  Doug Cockle  MyAnna Buring       Antonia Bernath       Mark Noble    6942
# ...

# %%
df.tail(3)
# Out:
#      RANKING                       VIDEO GAME NAME                Year  \
# 247       248       Assassin's Creed IV: Black Flag  (2013 Video Game)
# 248       249  Ni no Kuni: Wrath of the White Witch  (2011 Video Game)
# 249       250                         Borderlands 2  (2012 Video Game)
#
#                           genre  Rating  \
# 247  Action, Adventure, History     8.7
# 248          Adventure, Fantasy     8.7
# 249   Action, Adventure, Comedy     NaN
#
#                                                DETAILS         DIRECTOR   \
# 247  A video game where you play as sailor, private...     Ashraf Ismail
# 248  Oliver discovers that his mother is not dead, ...  Kentaro Motomura
# 249  A new group of adventurers arrives on the fron...    Paul Hellquist
#
#               ACTOR-1         ACTOR-2        ACTOR-3             ACTOR-4  \
# 247    Kate Fleetwood    Ralph Ineson  Stuart Martin  Michael McElhatton
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   RANKING           250 non-null    int64
#  1   VIDEO GAME NAME   250 non-null    object
#  2   Year              250 non-null    object
#  3   genre             249 non-null    object
#  4   Rating            249 non-null    float64
#  5   DETAILS           250 non-null    object
#  6   DIRECTOR          247 non-null    object
#  7   ACTOR-1           230 non-null    object
#  8   ACTOR-2           226 non-null    object
#  9   ACTOR-3           219 non-null    object
#  10  ACTOR-4           178 non-null    object
#  11  VOTES             250 non-null    int64
#  12  certificate       210 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 25.5+ KB

# %%
df.convert_dtypes().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   RANKING           250 non-null    Int64
#  1   VIDEO GAME NAME   250 non-null    string
#  2   Year              250 non-null    string
#  3   genre             249 non-null    string
#  4   Rating            249 non-null    Float64
#  5   DETAILS           250 non-null    string
#  6   DIRECTOR          247 non-null    string
#  7   ACTOR-1           230 non-null    string
#  8   ACTOR-2           226 non-null    string
#  9   ACTOR-3           219 non-null    string
#  10  ACTOR-4           178 non-null    string
#  11  VOTES             250 non-null    Int64
#  12  certificate       210 non-null    string
# dtypes: Float64(1), Int64(2), string(10)
# memory usage: 26.3 KB

# %%
df.columns
# Out:
# Index(['RANKING ', 'VIDEO GAME NAME ', 'Year', 'genre', 'Rating', 'DETAILS',
#        'DIRECTOR ', 'ACTOR-1', 'ACTOR-2', 'ACTOR-3', 'ACTOR-4', 'VOTES ',
#        'certificate'],
#       dtype='object')

# %% [markdown]
# ## Drop Unnecessary Columns

# %%
df.drop(['RANKING ','ACTOR-3','ACTOR-4'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                             VIDEO GAME NAME                Year  \
# 0  The Witcher 3: Wild Hunt - Blood and Wine  (2016 Video Game)
# 1                     Red Dead Redemption II  (2018 Video Game)
# 2                   The Witcher 3: Wild Hunt  (2015 Video Game)
# 3                             The Last of Us  (2013 Video Game)
# 4             Mass Effect: Legendary Edition  (2021 Video Game)
#
#                        genre  Rating  \
# 0   Action, Adventure, Drama     9.8
# 1   Action, Adventure, Crime     9.7
# 2   Action, Adventure, Drama     9.7
# 3   Action, Adventure, Drama     9.7
# 4  Action, Adventure, Sci-Fi     9.7
#
#                                              DETAILS             DIRECTOR   \
# 0  Geralt is in the southern province of Toussain...  Konrad Tomaszkiewicz
# 1  Amidst the decline of the Wild West at the tur...  Benjamin Byron Davis
# 2  A monster hunter for hire embarks on an epic j...  Konrad Tomaszkiewicz
# ...

# %% [markdown]
# ## Rename Columns in a suitable form

# %%
df.columns
# Out:
# Index(['VIDEO GAME NAME ', 'Year', 'genre', 'Rating', 'DETAILS', 'DIRECTOR ',
#        'ACTOR-1', 'ACTOR-2', 'VOTES ', 'certificate'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower().str.strip()
df.columns
# Out:
# Index(['video game name', 'year', 'genre', 'rating', 'details', 'director',
#        'actor-1', 'actor-2', 'votes', 'certificate'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['video_game_name', 'year', 'genre', 'rating', 'details', 'director',
#        'actor-1', 'actor-2', 'votes', 'certificate'],
#       dtype='object')

# %% [markdown]
# ## Describe Data

# %%
df.describe()
# Out:
#            rating         votes
# count  249.000000    250.000000
# mean     9.032530   5973.944000
# std      0.247133   8364.131818
# min      8.700000    254.000000
# 25%      8.800000    913.250000
# 50%      9.000000   2417.500000
# 75%      9.200000   6974.750000
# max      9.800000  56289.000000

# %%
df.describe(include='O')
# Out:
#         video_game_name               year                       genre  \
# count               250                250                         249
# unique              244                 34                          54
# top     Resident Evil 2  (1998 Video Game)  Action, Adventure, Fantasy
# freq                  2                 14                          64
#
#                                                   details      director  \
# count                                                 250           247
# unique                                                247           172
# top     Unravel mysteries as you journey through new p...  Hideo Kojima
# freq                                                    2             8
#
#              actor-1           actor-2 certificate
# count            230               226         210
# unique           199               205           6
# top     David Hayter  Malcolm McDowell           M
# ...

# %% [markdown]
# ## Check Duplicate Values

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Check Missing Values

# %%
df.shape
# Out:
# (249, 10)

# %%
df.isna().sum() / df.shape[0] *100
# Out:
# video_game_name     0.000000
# year                0.000000
# genre               0.401606
# rating              0.401606
# details             0.000000
# director            1.204819
# actor-1             8.032129
# actor-2             9.638554
# votes               0.000000
# certificate        16.064257
# dtype: float64

# %% [markdown]
# ## What is the minimum and maximum ratings ?

# %%
df['rating'].min()
# Out:
# 8.7

# %%
df['rating'].max()
# Out:
# 9.8

# %% [markdown]
# ## What are the Video Games with rating > 9 ?

# %%
df[df['rating']>9]
# Out:
#                                video_game_name               year  \
# 0    The Witcher 3: Wild Hunt - Blood and Wine  (2016 Video Game)
# 1                       Red Dead Redemption II  (2018 Video Game)
# 2                     The Witcher 3: Wild Hunt  (2015 Video Game)
# 3                               The Last of Us  (2013 Video Game)
# 4               Mass Effect: Legendary Edition  (2021 Video Game)
# ..                                         ...                ...
# 103                                Silent Hill  (1999 Video Game)
# 104                            Resident Evil 2  (1998 Video Game)
# 105                 The Curse of Monkey Island  (1997 Video Game)
# 106        Gabriel Knight: Sins of the Fathers  (1993 Video Game)
# 118                         Super Mario Galaxy  (2007 Video Game)
#
#                             genre  rating  \
# 0        Action, Adventure, Drama     9.8
# 1        Action, Adventure, Crime     9.7
# 2        Action, Adventure, Drama     9.7
# ...

# %%
list(df[df['rating']>9]['video_game_name'])
# Out:
# ['The Witcher 3: Wild Hunt - Blood and Wine',
#  'Red Dead Redemption II',
#  'The Witcher 3: Wild Hunt',
#  'The Last of Us',
#  'Mass Effect: Legendary Edition',
#  'God of War',
#  'Persona 5 Royal',
#  'The Legend of Zelda: Ocarina of Time',
#  'Metal Gear Solid',
#  'The Witcher 3: Wild Hunt - Hearts of Stone',
#  "Uncharted 4: A Thief's End",
#  'Grand Theft Auto V',
#  'Mass Effect 2',
#  'Half-Life: Alyx',
#  'Metal Gear Solid 3: Subsistence',
#  'Metal Gear Solid 3: Snake Eater',
#  'Star Wars: Knights of the Old Republic',
#  'Chrono Trigger',
#  'Final Fantasy VII',
#  'Bloodborne: The Old Hunters',
#  'The Legend of Zelda: Breath of the Wild',
#  'The Elder Scrolls V: Skyrim',
#  'Portal 2',
#  'Batman: Arkham City',
#  'Red Dead Redemption',
#  'Uncharted 2: Among Thieves',
#  'Metal Gear Solid 4: Guns of the Patriots',
#  'Grand Theft Auto: San Andreas',
#  'Half-Life 2',
#  'Silent Hill 2',
#  "Baldur's Gate II: Shadows of Amn",
#  'Planescape: Torment',
# ...

# %% [markdown]
# ## Top 10 movies per votes and user rating

# %%
df.sort_values(by=['votes','rating'],ascending=False)
# Out:
#                    video_game_name               year  \
# 3                   The Last of Us  (2013 Video Game)
# 11              Grand Theft Auto V  (2013 Video Game)
# 27   Grand Theft Auto: San Andreas  (2004 Video Game)
# 153            Grand Theft Auto IV  (2008 Video Game)
# 1           Red Dead Redemption II  (2018 Video Game)
# ..                             ...                ...
# 234      XCOM 2: War of the Chosen  (2017 Video Game)
# 173          The Pandora Directive  (1996 Video Game)
# 218                    Freespace 2  (1999 Video Game)
# 180   Enderal: The Shards of Order  (2016 Video Game)
# 212           Jet Set Radio Future  (2002 Video Game)
#
#                           genre  rating  \
# 3      Action, Adventure, Drama     9.7
# 11         Action, Crime, Drama     9.5
# 27                Action, Crime     9.4
# 153        Action, Crime, Drama     8.9
# 1      Action, Adventure, Crime     9.7
# ..                          ...     ...
# ...

# %% [markdown]
# ## Top 10 genres

# %%
df['genre'].value_counts().nlargest(10)
# Out:
# Action, Adventure, Fantasy    63
# Action, Adventure, Drama      27
# Action, Adventure, Sci-Fi     21
# Action, Adventure, Family     12
# Action, Adventure, Comedy     11
# Action, Crime, Drama          10
# Action, Adventure, Crime       9
# Action, Adventure, Mystery     8
# Adventure, Drama, Fantasy      5
# Adventure, Comedy, Fantasy     4
# Name: genre, dtype: int64

# %% [markdown]
# ## Top 10 Directories

# %%
df['director'].value_counts().nlargest(10)
# Out:
# Hideo Kojima         8
# Hidetaka Miyazaki    6
# Casey Hudson         5
# Tetsuya Nomura       5
# Feargus Urquhart     5
# Ken Levine           4
# Todd Howard          4
# Satoshi Tajiri       4
# Eiji Aonuma          4
# Sefton Hill          4
# Name: director, dtype: int64

# %% [markdown]
# ## Top 10 First Actors

# %%
df['actor-1'].value_counts().nlargest(10)
# Out:
# David Hayter         6
# Jennifer Hale        5
# Doug Cockle          4
# Mark Hamill          4
# Charles Martinet     4
# Robert Guillaume     3
# Michael Bell         2
# Glynnis Talken       2
# Haley Joel Osment    2
# Charlie Adler        2
# Name: actor-1, dtype: int64

# %%
df['actor-1'].value_counts().head(10)
# Out:
# David Hayter         6
# Jennifer Hale        5
# Doug Cockle          4
# Mark Hamill          4
# Charles Martinet     4
# Robert Guillaume     3
# Michael Bell         2
# Glynnis Talken       2
# Haley Joel Osment    2
# Charlie Adler        2
# Name: actor-1, dtype: int64

# %% [markdown]
# ## Top 10 Second Actors

# %%
list(df['actor-2'].value_counts().to_frame().index[:10])
# Out:
# ['Malcolm McDowell',
#  'Dennis Lenart',
#  'Nolan North',
#  'Takaya Kuroda',
#  'Earl Boen',
#  'Suzetta Miñet',
#  'Kevin Conroy',
#  'David Gallagher',
#  'Robert Culp',
#  'Fujiko Takimoto']

# %%
df['actor-2'].value_counts().nlargest(10)
# Out:
# Malcolm McDowell    3
# Dennis Lenart       3
# Nolan North         3
# Takaya Kuroda       3
# Earl Boen           2
# Suzetta Miñet       2
# Kevin Conroy        2
# David Gallagher     2
# Robert Culp         2
# Fujiko Takimoto     2
# Name: actor-2, dtype: int64

# %% [markdown]
# ## What is the most popular certificate in the world of video games ?

# %%
df['certificate'].value_counts().head(1)
# Out:
# M    111
# Name: certificate, dtype: int64

# %%
df['certificate'].value_counts().nlargest(1)
# Out:
# M    111
# Name: certificate, dtype: int64

# %%
df['certificate'].value_counts().to_frame().index[0]
# Out:
# 'M'
